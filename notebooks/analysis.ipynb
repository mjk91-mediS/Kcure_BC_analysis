# %%
# analysis.ipynb 예시 코드
import pandas as pd
import matplotlib.pyplot as plt

# 예제 데이터 로드
df = pd.DataFrame({
    'category': ['A', 'B', 'C'],
    'values': [10, 20, 30]
})

# 데이터 시각화
df.plot(kind='bar', x='category', y='values')
plt.title('Example Bar Plot')
plt.show()
